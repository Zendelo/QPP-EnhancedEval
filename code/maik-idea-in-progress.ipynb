# %%
import pyterrier as pt
from tira.third_party_integrations import ensure_pyterrier_is_loaded
from tira.rest_api_client import Client

ensure_pyterrier_is_loaded()
tira = Client()
# Out:
# Start PyTerrier with version=5.7, helper_version=0.0.7, no_download=True
# PyTerrier 0.9.2 has loaded Terrier 5.7 (built by craigm on 2022-11-10 18:30) and terrier-helper 0.0.7
#
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.
# No settings given in /root/.tira/.tira-settings.json. I will use defaults.

# %%
dataset = pt.get_dataset("irds:disks45/nocr/trec-robust-2004")
index = tira.get_run_output('ir-benchmarks/tira-ir-starter/Index (tira-ir-starter-pyterrier)', 'disks45-nocr-trec-robust-2004-20230209-training') + '/index'
queries = tira.download_dataset('ir-benchmarks', 'disks45-nocr-trec-robust-2004-20230209-training', truth_dataset=True) + '/queries.jsonl'

bm25_run = tira.get_run_output('ir-benchmarks/tira-ir-starter/BM25 Re-Rank (tira-ir-starter-pyterrier)', 'disks45-nocr-trec-robust-2004-20230209-training') + '/run.txt'

monot5_base_run = tira.get_run_output('ir-benchmarks/tira-ir-starter/MonoT5 Base (tira-ir-starter-gygaggle)', 'disks45-nocr-trec-robust-2004-20230209-training') + '/run.txt'
monot5_3b_run = tira.get_run_output('ir-benchmarks/tira-ir-starter/MonoT5 3b (tira-ir-starter-gygaggle)', 'disks45-nocr-trec-robust-2004-20230209-training') + '/run.txt'
monot5_large_run = tira.get_run_output('ir-benchmarks/tira-ir-starter/MonoT5 Large (tira-ir-starter-gygaggle)', 'disks45-nocr-trec-robust-2004-20230209-training') + '/run.txt'
dirichlet_run = tira.get_run_output('ir-benchmarks/tira-ir-starter/DirichletLM Re-Rank (tira-ir-starter-pyterrier)', 'disks45-nocr-trec-robust-2004-20230209-training') + '/run.txt'

tasb_run = 	tira.get_run_output('ir-benchmarks/tira-ir-starter/TASB msmarco-distilbert-base-dot (tira-ir-starter-beir)', 'disks45-nocr-trec-robust-2004-20230209-training') + '/run.txt'

# %%
# !python3 qpptk/qpptk/qpptk_main.py -ti {index} --jsonl_queries {queries} --run-file {tasb_run} --output idea-in-progress/tasb-predictions/ --stats_index_path idea-in-progress/tasb-predictions/stats --predPost --retrieve --cleanOutput
# Out:
# Start PyTerrier with version=5.7, helper_version=0.0.7, no_download=True
# PyTerrier 0.9.2 has loaded Terrier 5.7 (built by craigm on 2022-11-10 18:30) and terrier-helper 0.0.7
#
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.
# org.terrier.terms.PorterStemmer
# org.terrier.terms.PorterStemmer
# ...
# 100%|█████████████████████████████████████████| 537/537 [00:34<00:00, 15.35it/s]
# org.terrier.terms.PorterStemmer

# %%
# !python3 qpptk/qpptk/qpptk_main.py -ti {index} --jsonl_queries {queries} --run-file {monot5_3b_run} --output idea-in-progress/monot5-3b-predictions/ --stats_index_path idea-in-progress/monot5-3b-predictions/stats --predPost --retrieve --cleanOutput
# Out:
# Start PyTerrier with version=5.7, helper_version=0.0.7, no_download=True
# PyTerrier 0.9.2 has loaded Terrier 5.7 (built by craigm on 2022-11-10 18:30) and terrier-helper 0.0.7
#
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.
# org.terrier.terms.PorterStemmer
# org.terrier.terms.PorterStemmer
# ...
# 100%|█████████████████████████████████████████| 537/537 [00:37<00:00, 14.35it/s]
# org.terrier.terms.PorterStemmer

# %%
# !python3 qpptk/qpptk/qpptk_main.py -ti {index} --jsonl_queries {queries} --run-file {dirichlet_run} --output idea-in-progress/dirichlet-predictions/ --stats_index_path idea-in-progress/dirichlet-predictions/stats --predPost --retrieve --cleanOutput
# Out:
# Start PyTerrier with version=5.7, helper_version=0.0.7, no_download=True
# PyTerrier 0.9.2 has loaded Terrier 5.7 (built by craigm on 2022-11-10 18:30) and terrier-helper 0.0.7
#
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.
# org.terrier.terms.PorterStemmer
# org.terrier.terms.PorterStemmer
# ...
# 100%|█████████████████████████████████████████| 537/537 [00:38<00:00, 14.01it/s]
# org.terrier.terms.PorterStemmer
# /workspaces/QPP-EnhancedEval/code/qpptk/qpptk/post_retrieval_predictors.py:53: RuntimeWarning: divide by zero encountered in log
#   return (scores_vec * abs(np.log(scores_vec / mean))).mean() / self.ql_corpus_score
# /workspaces/QPP-EnhancedEval/code/qpptk/qpptk/post_retrieval_predictors.py:53: RuntimeWarning: invalid value encountered in multiply
#   return (scores_vec * abs(np.log(scores_vec / mean))).mean() / self.ql_corpus_score
# ...

# %%
# !python3 qpptk/qpptk/qpptk_main.py -ti {index} --jsonl_queries {queries} --run-file {bm25_run} --output idea-in-progress/bm25-predictions/ --stats_index_path idea-in-progress/bm25-predictions/stats --predPost --retrieve --cleanOutput
# Out:
# Start PyTerrier with version=5.7, helper_version=0.0.7, no_download=True
# PyTerrier 0.9.2 has loaded Terrier 5.7 (built by craigm on 2022-11-10 18:30) and terrier-helper 0.0.7
#
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.
# org.terrier.terms.PorterStemmer
# org.terrier.terms.PorterStemmer
# ...
# 100%|█████████████████████████████████████████| 537/537 [00:55<00:00,  9.62it/s]
# org.terrier.terms.PorterStemmer
# /workspaces/QPP-EnhancedEval/code/qpptk/qpptk/post_retrieval_predictors.py:53: RuntimeWarning: divide by zero encountered in log
#   return (scores_vec * abs(np.log(scores_vec / mean))).mean() / self.ql_corpus_score
# /workspaces/QPP-EnhancedEval/code/qpptk/qpptk/post_retrieval_predictors.py:53: RuntimeWarning: invalid value encountered in multiply
#   return (scores_vec * abs(np.log(scores_vec / mean))).mean() / self.ql_corpus_score

# %%
# !python3 qpptk/qpptk/qpptk_main.py -ti {index} --jsonl_queries {queries} --run-file {bm25_run} --use-scores-from-run-file {monot5_base_run} --output idea-in-progress/bm25-predictions-monot5-base/ --stats_index_path idea-in-progress/bm25-predictions-monot5-base/stats --predPost --retrieve --cleanOutput
# Out:
# Start PyTerrier with version=5.7, helper_version=0.0.7, no_download=True
# PyTerrier 0.9.2 has loaded Terrier 5.7 (built by craigm on 2022-11-10 18:30) and terrier-helper 0.0.7
#
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.
# org.terrier.terms.PorterStemmer
# org.terrier.terms.PorterStemmer
# ...
# 100%|█████████████████████████████████████████| 537/537 [00:31<00:00, 16.85it/s]
# org.terrier.terms.PorterStemmer

# %%
# !python3 qpptk/qpptk/qpptk_main.py -ti {index} --jsonl_queries {queries} --run-file {bm25_run} --use-scores-from-run-file {monot5_large_run} --output idea-in-progress/bm25-predictions-monot5-large/ --stats_index_path idea-in-progress/bm25-predictions-monot5-large/stats --predPost --retrieve --cleanOutput
# Out:
# Start PyTerrier with version=5.7, helper_version=0.0.7, no_download=True
# PyTerrier 0.9.2 has loaded Terrier 5.7 (built by craigm on 2022-11-10 18:30) and terrier-helper 0.0.7
#
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.
# org.terrier.terms.PorterStemmer
# org.terrier.terms.PorterStemmer
# ...
# 100%|█████████████████████████████████████████| 537/537 [00:37<00:00, 14.46it/s]
# org.terrier.terms.PorterStemmer

# %%
# !python3 qpptk/qpptk/qpptk_main.py -ti {index} --jsonl_queries {queries} --run-file {bm25_run} --use-scores-from-run-file {monot5_3b_run} --output idea-in-progress/bm25-predictions-monot5-3b/ --stats_index_path idea-in-progress/bm25-predictions-monot5-3b/stats --predPost --retrieve --cleanOutput
# Out:
# Start PyTerrier with version=5.7, helper_version=0.0.7, no_download=True
# PyTerrier 0.9.2 has loaded Terrier 5.7 (built by craigm on 2022-11-10 18:30) and terrier-helper 0.0.7
#
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.
# org.terrier.terms.PorterStemmer
# org.terrier.terms.PorterStemmer
# ...
# 100%|█████████████████████████████████████████| 537/537 [00:35<00:00, 15.18it/s]
# org.terrier.terms.PorterStemmer

# %%
def qpp_correlation_to_ground_truth(bm25, qpp, dataset, eval_metrics):
    import pandas as pd
    topics = dataset.get_topics(variant='title')
    df_eval = pt.Experiment([bm25], topics=topics, qrels=dataset.get_qrels(), eval_metrics=eval_metrics, perquery=True, names=['BM25'])
    df_predictions = qpp(topics)
    df_joined = pd.merge(df_eval, df_predictions, on=['qid'])
    ret = []

    for q in ['wig+5', 'wig+10', 'wig+20', 'wig+50', 'wig+100', 'wig+1000', 'nqc+5', 'nqc+10', 'nqc+20', 'nqc+50', 'nqc+100', 'nqc+1000', 'smv+5', 'smv+10', 'smv+20', 'smv+50', 'smv+100', 'smv+1000', 'clarity+5+100', 'clarity+10+100', 'clarity+20+100', 'clarity+50+100', 'clarity+100+100', 'clarity+1000+100']:
    
        ret += [{'QPP Method': q, 'Pearson Correlation': df_joined[['value', q]].corr(method='pearson').iloc[0].to_dict()[q], 'Kendall': df_joined[['value', q]].corr(method='kendall').iloc[0].to_dict()[q], 'Spearman': df_joined[['value', q]].corr(method='spearman').iloc[0].to_dict()[q]}]

    return pd.DataFrame(ret).sort_values('Pearson Correlation', ascending=False)

# %%
# !head -1 idea-in-progress/bm25-predictions-monot5-3b/queries.jsonl
# Out:
# {"qid":"301","wig+5":8.1538426386,"nqc+5":0.2302213445,"smv+5":0.1735291643,"clarity+5+1":8.4389762636,"clarity+5+2":7.2377404637,"clarity+5+3":6.6500359346,"clarity+5+4":6.2496529378,"clarity+5+5":5.9353293106,"clarity+5+10":5.2140229176,"clarity+5+100":4.1163406121,"clarity+5+1000":4.1162974043,"wig+10":8.3986639162,"nqc+10":0.2745438091,"smv+10":0.1982137628,"clarity+10+1":8.4389762636,"clarity+10+2":7.3374160851,"clarity+10+3":6.9327226033,"clarity+10+4":6.442240721,"clarity+10+5":6.4037441021,"clarity+10+10":5.6065822859,"clarity+10+100":4.2324150965,"clarity+10+1000":4.2323966464,"wig+20":7.6090500222,"nqc+20":0.265131287,"smv+20":0.169705112,"clarity+20+1":8.4389762636,"clarity+20+2":7.355133136,"clarity+20+3":6.6771405965,"clarity+20+4":6.4459559306,"clarity+20+5":6.3897175598,"clarity+20+10":5.7679897305,"clarity+20+100":4.1052893064,"clarity+20+1000":4.105207107,"wig+50":6.850329445,"nqc+50":0.2699966326,"smv+50":0.1646634367,"clarity+50+1":8.4389762636,"clarity+50+2":7.398
# ...

# %%
def load_predictions(f):
    import pandas as pd
    from pyterrier.apply import generic
    ret = pd.read_json(f, lines=True, dtype={'qid': str})
    cols = [i for i in ret.columns if i not in ['qid']]
    ret = {str(i['qid']): i for _, i in ret.iterrows()}

    def __transform_df(df):
        for col in cols:
            df[col] = df['qid'].apply(lambda i: ret[str(i)][col])
        return df

    return generic(__transform_df)

# %%
qpp_correlation_to_ground_truth(pt.io.read_results(tas), load_predictions('idea-in-progress/bm25-predictions-monot5-3b/queries.jsonl'), dataset, ['ndcg_cut_10', ])

# %%
qpp_correlation_to_ground_truth(pt.io.read_results(bm25_run), load_predictions('idea-in-progress/bm25-predictions-monot5-3b/queries.jsonl'), dataset, ['ndcg_cut_10', ])
# Out:
# /usr/local/lib/python3.10/dist-packages/pyterrier/pipelines.py:107: UserWarning: 1 topic(s) not found in qrels. Scores for these topics are given as NaN and should not contribute to averages.
#   warn(f'{backfill_count} topic(s) not found in qrels. Scores for these topics are given as NaN and should not contribute to averages.')
#           QPP Method  Pearson Correlation   Kendall  Spearman
# 23  clarity+1000+100             0.297331  0.218452  0.319161
# 22   clarity+100+100             0.242401  0.170052  0.246998
# 21    clarity+50+100             0.202920  0.136785  0.203184
# 20    clarity+20+100             0.197491  0.129023  0.192965
# 0              wig+5             0.188946  0.136198  0.199741
# 19    clarity+10+100             0.173608  0.122109  0.178816
# 15            smv+50             0.166172  0.106714  0.157793
# 1             wig+10             0.161279  0.112716  0.167670
# 9             nqc+50             0.138783  0.095756  0.143835
# ...

# %%
qpp_correlation_to_ground_truth(pt.io.read_results(bm25_run), load_predictions('idea-in-progress/bm25-predictions-monot5-large/queries.jsonl'), dataset, ['ndcg_cut_10', ])
# Out:
# /usr/local/lib/python3.10/dist-packages/pyterrier/pipelines.py:107: UserWarning: 1 topic(s) not found in qrels. Scores for these topics are given as NaN and should not contribute to averages.
#   warn(f'{backfill_count} topic(s) not found in qrels. Scores for these topics are given as NaN and should not contribute to averages.')
#           QPP Method  Pearson Correlation   Kendall  Spearman
# 23  clarity+1000+100             0.279941  0.202601  0.298859
# 22   clarity+100+100             0.235805  0.162224  0.240220
# 10           nqc+100             0.222925  0.144678  0.215852
# 21    clarity+50+100             0.213269  0.146178  0.214532
# 20    clarity+20+100             0.200061  0.128501  0.192217
# 9             nqc+50             0.199354  0.125500  0.188106
# 15            smv+50             0.182064  0.117151  0.175939
# 19    clarity+10+100             0.181858  0.119369  0.178206
# 16           smv+100             0.176015  0.112455  0.164884
# ...

# %%
qpp_correlation_to_ground_truth(pt.io.read_results(bm25_run), load_predictions('idea-in-progress/bm25-predictions-monot5-base/queries.jsonl'), dataset, ['ndcg_cut_10', ])
# Out:
# /usr/local/lib/python3.10/dist-packages/pyterrier/pipelines.py:107: UserWarning: 1 topic(s) not found in qrels. Scores for these topics are given as NaN and should not contribute to averages.
#   warn(f'{backfill_count} topic(s) not found in qrels. Scores for these topics are given as NaN and should not contribute to averages.')
#           QPP Method  Pearson Correlation   Kendall  Spearman
# 23  clarity+1000+100             0.258257  0.194513  0.287696
# 9             nqc+50             0.216954  0.139655  0.210442
# 22   clarity+100+100             0.208185  0.143895  0.215025
# 15            smv+50             0.206601  0.139264  0.208769
# 10           nqc+100             0.197725  0.124457  0.180996
# 21    clarity+50+100             0.177883  0.118390  0.174230
# 0              wig+5             0.167698  0.112976  0.164358
# 16           smv+100             0.155876  0.087342  0.129523
# 1             wig+10             0.150767  0.095691  0.140809
# ...

# %%
qpp_correlation_to_ground_truth(pt.io.read_results(bm25_run), load_predictions('idea-in-progress/bm25-predictions/queries.jsonl'), dataset, ['ndcg_cut_10', ])
# Out:
# /usr/local/lib/python3.10/dist-packages/pyterrier/pipelines.py:107: UserWarning: 1 topic(s) not found in qrels. Scores for these topics are given as NaN and should not contribute to averages.
#   warn(f'{backfill_count} topic(s) not found in qrels. Scores for these topics are given as NaN and should not contribute to averages.')
#           QPP Method  Pearson Correlation   Kendall  Spearman
# 10           nqc+100             0.462457  0.354427  0.507202
# 9             nqc+50             0.460322  0.356188  0.509381
# 8             nqc+20             0.368155  0.298916  0.433944
# 23  clarity+1000+100             0.281720  0.235448  0.340680
# 0              wig+5             0.281509  0.211312  0.306594
# 1             wig+10             0.276704  0.200615  0.291497
# 11          nqc+1000             0.272078  0.194483  0.282622
# 22   clarity+100+100             0.267740  0.225272  0.327238
# 21    clarity+50+100             0.262368  0.223706  0.325353
# ...

# %%
qpp_correlation_to_ground_truth(pt.io.read_results(bm25_run), load_predictions('idea-in-progress/monot5-3b-predictions/queries.jsonl'), dataset, ['ndcg_cut_10', ])
# Out:
# /usr/local/lib/python3.10/dist-packages/pyterrier/pipelines.py:107: UserWarning: 1 topic(s) not found in qrels. Scores for these topics are given as NaN and should not contribute to averages.
#   warn(f'{backfill_count} topic(s) not found in qrels. Scores for these topics are given as NaN and should not contribute to averages.')
#           QPP Method  Pearson Correlation   Kendall  Spearman
# 23  clarity+1000+100             0.297331  0.218452  0.319161
# 22   clarity+100+100             0.293091  0.212777  0.311435
# 21    clarity+50+100             0.290094  0.210428  0.307036
# 20    clarity+20+100             0.287910  0.206449  0.302137
# 19    clarity+10+100             0.287268  0.202144  0.295356
# 18     clarity+5+100             0.260596  0.177162  0.259691
# 14            smv+20             0.178812  0.115455  0.170733
# 8             nqc+20             0.164368  0.111085  0.162520
# 9             nqc+50             0.164234  0.114803  0.173650
# ...

# %%
qpp_correlation_to_ground_truth(pt.io.read_results(monot5_3b_run), load_predictions('idea-in-progress/monot5-3b-predictions/queries.jsonl'), dataset, ['ndcg_cut_10', ])
# Out:
# /usr/local/lib/python3.10/dist-packages/pyterrier/pipelines.py:107: UserWarning: 1 topic(s) not found in qrels. Scores for these topics are given as NaN and should not contribute to averages.
#   warn(f'{backfill_count} topic(s) not found in qrels. Scores for these topics are given as NaN and should not contribute to averages.')
#           QPP Method  Pearson Correlation   Kendall  Spearman
# 14            smv+20             0.271772  0.179331  0.265175
# 8             nqc+20             0.255656  0.168275  0.250367
# 9             nqc+50             0.235714  0.165088  0.249465
# 15            smv+50             0.220694  0.147399  0.223921
# 23  clarity+1000+100             0.205987  0.144603  0.213371
# 22   clarity+100+100             0.200144  0.141091  0.207027
# 21    clarity+50+100             0.196198  0.138619  0.203131
# 13            smv+10             0.190493  0.134652  0.201750
# 20    clarity+20+100             0.188698  0.128669  0.191014
# ...

# %%
qpp_correlation_to_ground_truth(pt.io.read_results(dirichlet_run), load_predictions('idea-in-progress/dirichlet-predictions/queries.jsonl'), dataset, ['ndcg_cut_10', ])
# Out:
# /usr/local/lib/python3.10/dist-packages/pyterrier/pipelines.py:107: UserWarning: 1 topic(s) not found in qrels. Scores for these topics are given as NaN and should not contribute to averages.
#   warn(f'{backfill_count} topic(s) not found in qrels. Scores for these topics are given as NaN and should not contribute to averages.')
#           QPP Method  Pearson Correlation   Kendall  Spearman
# 9             nqc+50             0.475283  0.363273  0.509555
# 10           nqc+100             0.463473  0.330830  0.465296
# 23  clarity+1000+100             0.400821  0.304849  0.441586
# 22   clarity+100+100             0.387609  0.288530  0.422133
# 21    clarity+50+100             0.384282  0.283895  0.415216
# 20    clarity+20+100             0.380293  0.281414  0.408809
# 19    clarity+10+100             0.367162  0.264116  0.388863
# 18     clarity+5+100             0.362036  0.262223  0.384062
# 8             nqc+20             0.352186  0.318035  0.452020
# ...

# %%
qpp_correlation_to_ground_truth(pt.io.read_results(tasb_run), load_predictions('idea-in-progress/tasb-predictions/queries.jsonl'), dataset, ['ndcg_cut_10', ])
# Out:
# /usr/local/lib/python3.10/dist-packages/pyterrier/pipelines.py:107: UserWarning: 1 topic(s) not found in qrels. Scores for these topics are given as NaN and should not contribute to averages.
#   warn(f'{backfill_count} topic(s) not found in qrels. Scores for these topics are given as NaN and should not contribute to averages.')
#           QPP Method  Pearson Correlation   Kendall  Spearman
# 9             nqc+50             0.362994  0.281135  0.417103
# 8             nqc+20             0.334834  0.273627  0.410473
# 10           nqc+100             0.324611  0.254630  0.377288
# 7             nqc+10             0.269630  0.227016  0.344634
# 23  clarity+1000+100             0.263652  0.200838  0.293189
# 22   clarity+100+100             0.259267  0.197705  0.288425
# 21    clarity+50+100             0.254336  0.194571  0.283784
# 20    clarity+20+100             0.242314  0.186476  0.271842
# 19    clarity+10+100             0.224332  0.171266  0.250670
# ...

# %%
qpp_correlation_to_ground_truth(pt.io.read_results(monot5_3b_run), load_predictions('idea-in-progress/bm25-predictions/queries.jsonl'), dataset, ['ndcg_cut_10', ])
# Out:
# /usr/local/lib/python3.10/dist-packages/pyterrier/pipelines.py:107: UserWarning: 1 topic(s) not found in qrels. Scores for these topics are given as NaN and should not contribute to averages.
#   warn(f'{backfill_count} topic(s) not found in qrels. Scores for these topics are given as NaN and should not contribute to averages.')
#           QPP Method  Pearson Correlation   Kendall  Spearman
# 9             nqc+50             0.282463  0.197446  0.292077
# 8             nqc+20             0.265958  0.180081  0.264895
# 10           nqc+100             0.251506  0.176570  0.260652
# 7             nqc+10             0.178078  0.136313  0.201397
# 23  clarity+1000+100             0.138866  0.101649  0.149602
# 22   clarity+100+100             0.128110  0.092740  0.136104
# 21    clarity+50+100             0.122493  0.089683  0.131691
# 20    clarity+20+100             0.111473  0.081814  0.117454
# 0              wig+5             0.105758  0.060612  0.092119
# ...

# %%
qpp_correlation_to_ground_truth(pt.io.read_results(monot5_3b_run), load_predictions('idea-in-progress/monot5-3b-predictions/queries.jsonl'), dataset, ['ndcg_cut_10', ])
# Out:
# /usr/local/lib/python3.10/dist-packages/pyterrier/pipelines.py:107: UserWarning: 1 topic(s) not found in qrels. Scores for these topics are given as NaN and should not contribute to averages.
#   warn(f'{backfill_count} topic(s) not found in qrels. Scores for these topics are given as NaN and should not contribute to averages.')
#           QPP Method  Pearson Correlation   Kendall  Spearman
# 14            smv+20             0.271772  0.179331  0.265175
# 8             nqc+20             0.255656  0.168275  0.250367
# 9             nqc+50             0.235714  0.165088  0.249465
# 15            smv+50             0.220694  0.147399  0.223921
# 23  clarity+1000+100             0.205987  0.144603  0.213371
# 22   clarity+100+100             0.200144  0.141091  0.207027
# 21    clarity+50+100             0.196198  0.138619  0.203131
# 13            smv+10             0.190493  0.134652  0.201750
# 20    clarity+20+100             0.188698  0.128669  0.191014
# ...
